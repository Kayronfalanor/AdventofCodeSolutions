# %%
direcinput = [14, 14, 21, 13, 25, 12, 15, 11, 24, 13, 25, 12, 23, 24, 23, 11, 15, 11, 23, 21, 13, 21, 12, 12, 22, 15, 23, 24, 14, 14, 12, 24, 21, 15, 21, 24, 14, 21, 11, 22, 15, 22, 23, 12, 11, 2194, 12, 24, 149, 11, 13, 25, 24, 21, 14, 12, 11, 25, 13, 25, 24, 14, 14, 22, 23, 178, 25, 14, 1191, 14, 13, 11, 22, 11, 13, 21, 13, 14, 12, 22, 11, 14, 25, 12, 22, 24, 22, 11, 12, 23, 15, 12, 23, 23, 13, 21, 21, 15, 24, 24, 22, 15, 11, 14, 23, 25, 24, 15, 24, 15, 14, 23, 22, 25, 14, 13, 23, 11, 25, 15, 11, 23, 12, 25, 15, 23, 11, 14, 25, 14, 12, 13, 24, 25, 13, 14, 25, 25, 14, 24, 24, 11, 15, 13, 21, 24, 23, 24, 11, 25, 21, 12, 12, 14, 14, 25, 14, 11, 21, 21, 23, 25, 22, 14, 23, 25, 24, 21, 13]

def directions(input):
    direction = "North"
    x = 0
    y = 0
    visitedlocations = []
    currentlocation = ""
    for inst in input:
        number = str(inst)
        if currentlocation in visitedlocations:
                        break
        elif number[0] == "1":
            if direction == "North":
                direction = "East"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    x += 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
            elif direction == "East":
                direction = "South"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    y -= 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
            elif direction == "South":
                direction = "West"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    x -= 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
            elif direction == "West":
                direction = "North"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    y += 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
        if number[0] == "2":
            if direction == "North":
                direction = "West"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    x -= 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
            elif direction == "West":
                direction = "South"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    y -= 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
            elif direction == "South":
                direction = "East"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    x += 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
            elif direction == "East":
                direction = "North"
                num = number[1:]
                numb = int(num)
                for times in range(numb):
                    y += 1
                    visitedlocations.append(currentlocation)
                    currentlocation = f"{x},{y}"
                    if currentlocation in visitedlocations:
                        print(currentlocation)
                        break
                continue
directions(direcinput)
# Out:
# -34,-97
