# %%
inputa = "737	1866	1565	1452	1908	1874	232	1928	201	241	922	281	1651	1740	1012	1001"
inputb = "339	581	41	127	331	133	51	131	129	95	499	527	518	435	508	494"
inputc = "1014	575	1166	259	152	631	1152	1010	182	943	163	158	1037	1108	1092	887"
inputd = "56	491	409	1263	1535	41	1431	1207	1393	700	1133	53	131	466	202	62"
inpute = "632	403	118	352	253	672	711	135	116	665	724	780	159	133	90	100"
inputf = "1580	85	1786	1613	1479	100	94	1856	546	76	1687	1769	1284	1422	1909	1548"
inputg = "479	356	122	372	786	1853	979	116	530	123	1751	887	109	1997	160	1960"
inputh = "446	771	72	728	109	369	300	746	86	910	566	792	616	84	338	57"
inputi = "6599	2182	200	2097	4146	7155	7018	1815	1173	4695	201	7808	242	3627	222	7266"
inputj = "1729	600	651	165	1780	2160	626	1215	149	179	1937	1423	156	129	634	458"
inputk = "1378	121	146	437	1925	2692	130	557	2374	2538	2920	2791	156	317	139	541"
inputl = "1631	176	1947	259	2014	153	268	752	2255	347	227	2270	2278	544	2379	349"
inputm = "184	314	178	242	145	410	257	342	183	106	302	320	288	151	449	127"
inputn = "175	5396	1852	4565	4775	665	4227	171	4887	181	2098	4408	2211	3884	2482	158"
inputo = "1717	3629	244	258	281	3635	235	4148	3723	4272	3589	4557	4334	4145	3117	4510"
inputp = "55	258	363	116	319	49	212	44	303	349	327	330	316	297	313	67"

alph = "abcdefghijklmnop"

for letter in alph:
    rinput = input + 

rinputa = inputa.replace("	",",")
rinputb = inputb.replace("	",",")
rinputc = inputc.replace("	",",")
rinputd = inputd.replace("	",",")
rinpute = inpute.replace("	",",")
rinputf = inputf.replace("	",",")
rinputg = inputg.replace("	",",")
rinputh = inputh.replace("	",",")
rinputi = inputi.replace("	",",")
rinputj = inputj.replace("	",",")
rinputk = inputk.replace("	",",")
rinputl = inputl.replace("	",",")
rinputm = inputm.replace("	",",")
rinputn = inputn.replace("	",",")
rinputo = inputo.replace("	",",")
rinputp = inputp.replace("	",",")

doneputa = rinputa.split(",")
doneputb = rinputb.split(",")
doneputc = rinputc.split(",")
doneputd = rinputd.split(",")
donepute = rinpute.split(",")
doneputf = rinputf.split(",")
doneputg = rinputg.split(",")
doneputh = rinputh.split(",")
doneputi = rinputi.split(",")
doneputj = rinputj.split(",")
doneputk = rinputk.split(",")
doneputl = rinputl.split(",")
doneputm = rinputm.split(",")
doneputn = rinputn.split(",")
doneputo = rinputo.split(",")
doneputp = rinputp.split(",")

def checksum(input):
    chcksumlist = []
    for num in input:
        chck = int(num)
        chcksumlist.append(chck)
        continue
    chcksum = max(chcksumlist) - min(chcksumlist)
    print(chcksum)


checksum(doneputa)
checksum(doneputb)
checksum(doneputc)
checksum(doneputd)
checksum(donepute)
checksum(doneputf)
checksum(doneputg)
checksum(doneputh) 
checksum(doneputi)
checksum(doneputj)
checksum(doneputk)
checksum(doneputl)
checksum(doneputm)
checksum(doneputn)
checksum(doneputo)
checksum(doneputp)

answer = 1727+540+1014+1494+690+1833+1888+853+7608+2031+2799+2226+343+5238+4322+319
print(answer)
# Out:
# 1727
# 540
